# %% [markdown]
# QUESTION 4 - PART a:

# %%
from matplotlib.image import imread #for image read
import matplotlib.pyplot as plt
import numpy as np
import os
plt.rcParams['figure.figsize']=[16, 8]
A= imread ('/Users/peter/Desktop/car photo.jpg') #for upload photo
X= np.mean(A, -1)
img= plt.imshow(256-X)
img.set_cmap('gray')
plt.axis('off')
plt.show()

# %%
U, S, VT= np.linalg.svd(X,full_matrices=False)
S = np.diag(S)

j = 0
for r in (5, 10, 20, 60, 100): #construct approximate image 
    Xapprox = U [:,:r] @ S[0:r, :r] @ VT[:r, :]
    plt.figure(j+1)
    img = plt.imshow(256-Xapprox)
    img.set_cmap('gray')
    plt.axis('off')
    plt.title('r = ' + str(r))
    plt.show()

# %% [markdown]
# I will use the diagram below(Sigular Values: Cumulative Sum) to answer the rest of the question.

# %%
plt.figure(2)
plt.plot(np.cumsum(np.diag(S))/np.sum(np.diag(S)))
plt.title('Sigular Values: Cumulative Sum')
plt.show()
